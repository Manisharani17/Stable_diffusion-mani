# %%
#!pip install gtts

# %%
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('''I am manisha,i have completed BSC computer science , my passed out in 2024, 
now iam take the Data science coching in Naresh IT Technology ''',lang='hi',tld='com')

text_to_speech.save('text_to_speech_gtts.wav')
sound_file = 'text_to_speech_gtts.wav'

Audio(sound_file, autoplay= False)
# Out:
# Requirement already satisfied: gtts in c:\users\dell\anaconda\lib\site-packages (2.5.4)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\dell\anaconda\lib\site-packages (from gtts) (2.32.2)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\dell\anaconda\lib\site-packages (from gtts) (8.1.7)
# Requirement already satisfied: colorama in c:\users\dell\anaconda\lib\site-packages (from click<8.2,>=7.1->gtts) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda\lib\site-packages (from requests<3,>=2.27->gtts) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda\lib\site-packages (from requests<3,>=2.27->gtts) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda\lib\site-packages (from requests<3,>=2.27->gtts) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda\lib\site-packages (from requests<3,>=2.27->gtts) (2024.6.2)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#!pip install pyttsx3

# %%
# !pip install pyttsx3
import pyttsx3
from IPython.display import Audio

text = ''' I am manisha,i have completed BSC computer science , my passed out in 2024, 
now iam take the Data science coching in Naresh IT Technology.'''

audio = pyttsx3.init()
audio.setProperty('rate', 150)
audio.setProperty('volume', 0.8)

# change the voices
voice = audio.getProperty('voices')

# 0 for male and 1 for female
audio.setProperty('voice', voice[0].id)      # for male voice   
#audio.setProperty('voice', voice[1].id)       # for female voice

# text-to speech conversion
audio.say(text)

# save the audio file
audio.save_to_file(text, 'test_male_Voice.mp3')
#audio.save_to_file(text, 'test_female_Voice.mp3')

audio.runAndWait()
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\dell\anaconda\lib\site-packages (2.98)
# Requirement already satisfied: comtypes in c:\users\dell\anaconda\lib\site-packages (from pyttsx3) (1.4.10)
# Requirement already satisfied: pypiwin32 in c:\users\dell\anaconda\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\dell\anaconda\lib\site-packages (from pyttsx3) (305.1)
